# %% [markdown]
# <a href="https://colab.research.google.com/github/rakenny1985/THA-3/blob/master/THA3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file= 'MotherJones_MassShooting_Clean.xlsx'
xl=pd.ExcelFile(file)
df1=xl.parse('5ae6f6d7-6df1-4887-9ded-35c84f3')
df1.head() #importing first dataframe
# Out:
#                   Date                         Case_name  \
# 0  2018-11-07T00:00:00  Thousand Oaks nightclub shooting
# 1  2018-10-27T00:00:00   Tree of Life synagogue shooting
# 2  2018-09-20T00:00:00       Rite Aid warehouse shooting
# 3  2018-09-12T00:00:00             T&T Trucking shooting
# 4  2018-09-06T00:00:00       Fifth Third Center shooting
#
#   Location_address_original           City         State  Year  \
# 0         Thousand Oaks, CA  Thousand Oaks    California  2018
# 1            Pittsburgh, PA     Pittsburgh  Pennsylvania  2018
# 2              Perryman, MD       Perryman      Maryland  2018
# 3           Bakersfield, CA    Bakersfield    California  2018
# 4            Cincinnati, OH     Cincinnati          Ohio  2018
#
#                                              Summary  Fatalities  Injured  \
# 0  Ian David Long, 28, dressed in black and armed...          12       22
# 1  Robert D. Bowers, 46, shouted anti-Semitic slu...          11        6
# ...

# %%
file2= 'SPLC_HateGroups_Clean.xlsx'
xl=pd.ExcelFile(file2)
df2=xl.parse('26422446-e4f1-471f-a912-c8c94b9')
df2.head() #importing second data frame
# Out:
#                   Name          Ideology        City    State  is_statewide  \
# 0      Nation of Islam  Black Separatist  Birmingham  Alabama         False
# 1  League of the South   Neo-Confederate  Tuscaloosa  Alabama         False
# 2  League of the South   Neo-Confederate    Wetumpka  Alabama         False
# 3      Nation of Islam  Black Separatist  Huntsville  Alabama         False
# 4      Nation of Islam  Black Separatist      Mobile  Alabama         False
#
#    is_headquarters  Latitude  Longitude  \
# 0            False     33.44     -86.86
# 1            False     33.20     -87.56
# 2            False     32.59     -86.21
# 3            False     34.73     -86.58
# 4            False     30.69     -88.05
#
#                                        Ideology_link  \
# 0  https://www.splcenter.org/fighting-hate/extrem...
# 1  https://www.splcenter.org/fighting-hate/extrem...
# 2  https://www.splcenter.org/fighting-hate/extrem...
# ...

# %%
count = df1['State'].value_counts()
print(count)
count2= df2['State'].value_counts()
print(count2)
#Counting the instances of mass murders and hate groups by state
# Out:
# California              19
# Florida                 10
# Texas                    9
# Washington               7
# Colorado                 6
# Wisconsin                4
# New York                 4
# Pennsylvania             4
# Connecticut              3
# Maryland                 3
# Ohio                     3
# South Carolina           2
# Oregon                   2
# Georgia                  2
# Kentucky                 2
# Minnesota                2
# Tennessee                2
# Nevada                   2
# North Carolina           2
# Illinois                 2
# Michigan                 2
# Hawaii                   1
# Iowa                     1
# Nebraska                 1
# Mississippi              1
# Missouri                 1
# District of Columbia     1
# Kansas                   1
# Arkansas                 1
# Arizona                  1
# Utah                     1
# Oklahoma                 1
# Virginia                 1
# Massachusetts            1
# ...

# %%
frames = [count,count2]



new_dataframe= pd.concat(frames, axis=1, join='inner', join_axes=None, ignore_index=False,
          keys=None, levels=None, names=None, verify_integrity=False,
          copy=True)
print(new_dataframe)

for col in new_dataframe.columns:
  print(col) #combining the counts into one dataset
# Out:
#                       State  State
# California               19     79
# Florida                  10     63
# Texas                     9     55
# Washington                7     21
# Colorado                  6     16
# Wisconsin                 4      9
# New York                  4     47
# Pennsylvania              4     40
# Connecticut               3      5
# Maryland                  3     18
# Ohio                      3     35
# South Carolina            2     12
# Oregon                    2     11
# Georgia                   2     32
# Kentucky                  2     23
# Minnesota                 2     10
# Tennessee                 2     38
# Nevada                    2      4
# North Carolina            2     31
# Illinois                  2     32
# Michigan                  2     28
# Iowa                      1      4
# Nebraska                  1      5
# Mississippi               1     18
# Missouri                  1     24
# District of Columbia      1     21
# ...

# %%
new_dataframe.columns= ['Count_Mass_Murders', 'Count_Hate_Groups']
new_dataframe #updated column headers
# Out:
#                       Count_Mass_Murders  Count_Hate_Groups
# California                            19                 79
# Florida                               10                 63
# Texas                                  9                 55
# Washington                             7                 21
# Colorado                               6                 16
# Wisconsin                              4                  9
# New York                               4                 47
# Pennsylvania                           4                 40
# Connecticut                            3                  5
# Maryland                               3                 18
# Ohio                                   3                 35
# South Carolina                         2                 12
# Oregon                                 2                 11
# Georgia                                2                 32
# Kentucky                               2                 23
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
ax=new_dataframe.plot.scatter (x='Count_Mass_Murders', y='Count_Hate_Groups')
#created scatter plot
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
import seaborn as sns; sns.set(color_codes=True)

ax1 = sns.regplot(x="Count_Mass_Murders", y="Count_Hate_Groups", data=new_dataframe)
#created simple regression - slight correlation
